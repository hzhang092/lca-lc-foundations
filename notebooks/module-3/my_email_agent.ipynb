# %% [markdown]
# # Design
# context: user password
# states: 1. legit user or not
#
# # agents:
# 1. coordinator: checks password,
#
# ### tools:
# 1. password_checker: checks if the password matches,  @before_agent
# 2. read email
# 3. send email
#
# ### build in middleware:
# HumanInTheLoop
