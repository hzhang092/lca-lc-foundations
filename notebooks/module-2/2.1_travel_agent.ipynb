# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

from langchain_nvidia_ai_endpoints import ChatNVIDIA
model = ChatNVIDIA(model="meta/llama-3.3-70b-instruct")

agent = create_agent(
    model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st, 2026")]},
    config
    )
# Out:
# Session termination failed:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 from langchain.messages import HumanMessage
#       3 config = {"configurable": {"thread_id": "1"}}
# ----> 5 response = await agent.ainvoke(
#       6     {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st, 2026")]},
#       7     config
#       8     )
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\pregel\main.py:3161, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3158 chunks: list[dict[str, Any] | Any] = []
#    3159 interrupts: list[Interrupt] = []
# -> 3161 async for chunk in self.astream(
#    3162     input,
#    3163     config,
#    3164     context=context,
#    3165     stream_mode=["updates", "values"]
#    3166     if stream_mode == "values"
#    3167     else stream_mode,
#    3168     print_mode=print_mode,
#    3169     output_keys=output_keys,
#    3170     interrupt_before=interrupt_before,
#    3171     interrupt_after=interrupt_after,
#    3172     durability=durability,
#    3173     **kwargs,
#    3174 ):
#    3175     if stream_mode == "values":
#    3176         if len(chunk) == 2:
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\pregel\main.py:2974, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2972 for task in await loop.amatch_cached_writes():
#    2973     loop.output_writes(task.id, task.writes, cached=True)
# -> 2974 async for _ in runner.atick(
#    2975     [t for t in loop.tasks.values() if not t.writes],
#    2976     timeout=self.step_timeout,
#    2977     get_waiter=get_waiter,
#    2978     schedule_task=loop.aaccept_push,
#    2979 ):
#    2980     # emit output
#    2981     for o in _output(
#    2982         stream_mode,
#    2983         print_mode,
#    (...)   2986         asyncio.QueueEmpty,
#    2987     ):
#    2988         yield o
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\pregel\_retry.py:138, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     136         break
#     137     else:
# --> 138         return await task.proc.ainvoke(task.input, config)
#     139 except ParentCommand as exc:
#     140     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\_internal\_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     703     # run in context
#     704     with set_config_context(config, run) as context:
# --> 705         input = await asyncio.create_task(
#     706             step.ainvoke(input, config, **kwargs), context=context
#     707         )
#     708 else:
#     709     input = await step.ainvoke(input, config, **kwargs)
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     471         await run_manager.on_chain_end(ret)
#     472 else:
# --> 473     ret = await self.afunc(*args, **kwargs)
#     474 if self.recurse and isinstance(ret, Runnable):
#     475     return await ret.ainvoke(input, config)
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain\agents\factory.py:1309, in create_agent.<locals>.amodel_node(state, runtime)
#    1297 request = ModelRequest(
#    1298     model=model,
#    1299     tools=default_tools,
#    (...)   1305     runtime=runtime,
#    1306 )
#    1308 if awrap_model_call_handler is None:
# -> 1309     model_response = await _execute_model_async(request)
#    1310     return _build_commands(model_response)
#    1312 result = await awrap_model_call_handler(request, _execute_model_async)
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain\agents\factory.py:1281, in create_agent.<locals>._execute_model_async(request)
#    1278 if request.system_message:
#    1279     messages = [request.system_message, *messages]
# -> 1281 output = await model_.ainvoke(messages)
#    1282 if name:
#    1283     output.name = name
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_core\runnables\base.py:5708, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5701 @override
#    5702 async def ainvoke(
#    5703     self,
#    (...)   5706     **kwargs: Any | None,
#    5707 ) -> Output:
# -> 5708     return await self.bound.ainvoke(
#    5709         input,
#    5710         self._merge_configs(config),
#    5711         **{**self.kwargs, **kwargs},
#    5712     )
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_core\language_models\chat_models.py:425, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     415 @override
#     416 async def ainvoke(
#     417     self,
#    (...)    422     **kwargs: Any,
#     423 ) -> AIMessage:
#     424     config = ensure_config(config)
# --> 425     llm_result = await self.agenerate_prompt(
#     426         [self._convert_input(input)],
#     427         stop=stop,
#     428         callbacks=config.get("callbacks"),
#     429         tags=config.get("tags"),
#     430         metadata=config.get("metadata"),
#     431         run_name=config.get("run_name"),
#     432         run_id=config.pop("run_id", None),
#     433         **kwargs,
#     434     )
#     435     return cast(
#     436         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     437     )
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_core\language_models\chat_models.py:1134, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1125 @override
#    1126 async def agenerate_prompt(
#    1127     self,
#    (...)   1131     **kwargs: Any,
#    1132 ) -> LLMResult:
#    1133     prompt_messages = [p.to_messages() for p in prompts]
# -> 1134     return await self.agenerate(
#    1135         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1136     )
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_core\language_models\chat_models.py:1054, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1041 run_managers = await callback_manager.on_chat_model_start(
#    1042     self._serialized,
#    1043     messages_to_trace,
#    (...)   1048     run_id=run_id,
#    1049 )
#    1051 input_messages = [
#    1052     _normalize_messages(message_list) for message_list in messages
#    1053 ]
# -> 1054 results = await asyncio.gather(
#    1055     *[
#    1056         self._agenerate_with_cache(
#    1057             m,
#    1058             stop=stop,
#    1059             run_manager=run_managers[i] if run_managers else None,
#    1060             **kwargs,
#    1061         )
#    1062         for i, m in enumerate(input_messages)
#    1063     ],
#    1064     return_exceptions=True,
#    1065 )
#    1066 exceptions = []
#    1067 for i, res in enumerate(results):
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_core\language_models\chat_models.py:1361, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1359     result = generate_from_stream(iter(chunks))
#    1360 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1361     result = await self._agenerate(
#    1362         messages, stop=stop, run_manager=run_manager, **kwargs
#    1363     )
#    1364 else:
#    1365     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_nvidia_ai_endpoints\chat_models.py:756, in ChatNVIDIA._agenerate(self, messages, stop, run_manager, **kwargs)
#     752 """Async version of `_generate`."""
#     753 _, payload, extra_headers = self._prepare_inputs_and_payload(
#     754     messages, stop, stream=False, **kwargs
#     755 )
# --> 756 response = await self._client.aget_req(
#     757     payload=payload, extra_headers=extra_headers
#     758 )
#     759 return self._process_generate_response(
#     760     response, run_manager, _is_structured_output(payload)
#     761 )
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_nvidia_ai_endpoints\_common.py:771, in _NVIDIAClient.aget_req(self, payload, extra_headers)
#     765 async def aget_req(
#     766     self,
#     767     payload: dict = {},
#     768     extra_headers: dict = {},
#     769 ) -> str:
#     770     """Async version of `get_req`."""
# --> 771     response, session = await self._post_async(
#     772         self.infer_url, payload, extra_headers=extra_headers
#     773     )
#     774     try:
#     775         response = await self._wait_async(response, session)
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\langchain_nvidia_ai_endpoints\_common.py:541, in _NVIDIAClient._post_async(self, invoke_url, payload, extra_headers)
#     539 session = self.get_async_session_fn()
#     540 try:
# --> 541     self.last_response = response = await session.post(
#     542         **self.__add_authorization(self.last_inputs)
#     543     )
#     544     await self._try_raise_async(response)
#     545     return response, session
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\aiohttp\client.py:779, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     776     handler = _connect_and_send_request
#     778 try:
# --> 779     resp = await handler(req)
#     780 # Client connector errors should not be retried
#     781 except (
#     782     ConnectionTimeoutError,
#     783     ClientConnectorError,
#     784     ClientConnectorCertificateError,
#     785     ClientConnectorSSLError,
#     786 ):
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\aiohttp\client.py:757, in ClientSession._request.<locals>._connect_and_send_request(req)
#     755 resp = await req.send(conn)
#     756 try:
# --> 757     await resp.start(conn)
#     758 except BaseException:
#     759     resp.close()
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\aiohttp\client_reqrep.py:539, in ClientResponse.start(self, connection)
#     537 try:
#     538     protocol = self._protocol
# --> 539     message, payload = await protocol.read()  # type: ignore[union-attr]
#     540 except http.HttpProcessingError as exc:
#     541     raise ClientResponseError(
#     542         self.request_info,
#     543         self.history,
#    (...)    546         headers=exc.headers,
#     547     ) from exc
#
# File c:\Users\henry\anaconda3\envs\twelve\Lib\site-packages\aiohttp\streams.py:703, in DataQueue.read(self)
#     701 self._waiter = self._loop.create_future()
#     702 try:
# --> 703     await self._waiter
#     704 except (asyncio.CancelledError, asyncio.TimeoutError):
#     705     self._waiter = None
#
# CancelledError:

# %%
from pprint import pprint

pprint(response)

# %%
print(response["messages"][-1].content)
